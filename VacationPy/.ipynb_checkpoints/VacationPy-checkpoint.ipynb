# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import csv
import json

# Import API key
from api_keys import g_key
# Access maps with unique API key
gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
csvpath = os.path.join('..', 'WeatherPy/output_data', 'clean_city_data.csv')

city_data = pd.read_csv(csvpath)

city_data
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       barcelona  10.18  -65.04     80.60      74.0         0.0        4.70
# 1        portland -54.07  132.47     81.00      56.0         1.0        6.93
# 2          aykhal  67.13  107.26     44.60      93.0        90.0        8.95
# 3         qaanaaq  89.15  -80.58     48.67      54.0         0.0        3.02
# 4    punta arenas -55.51  -99.24     30.20      92.0        10.0        6.93
# ..            ...    ...     ...       ...       ...         ...         ...
# 578        labuan   7.94  113.04     77.00      94.0        75.0        2.24
# 579       dunkirk  51.41    2.14     63.00      55.0         0.0        9.17
# 580    baruun-urt  45.34  115.94     62.82      63.0         0.0        7.27
# 581       tkibuli  42.27   43.03     71.60      94.0        90.0        5.82
# 582     pokosnoye  55.19  100.73     55.83      75.0        99.0        5.61
#
#     Country          Date
# 0        ES  1.595358e+09
# 1        US  1.595358e+09
# 2        RU  1.595358e+09
# 3        GL  1.595358e+09
# 4        CL  1.595358e+09
# ..      ...           ...
# 578      MY  1.595358e+09
# 579      FR  1.595358e+09
# 580      MN  1.595358e+09
# 581      GE  1.595358e+09
# 582      RU  1.595358e+09
#
# [583 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Load coordinates list

# Create an empty list 
row_list = []
location_row_list =[] 
weight_row_list =[] 

# Iterate over each row 
for index, rows in city_data.iterrows(): 
    # Create list for the current row 
    my_list =[rows.Lat, rows.Lng, rows.Humidity] 
    location_row =[rows.Lat, rows.Lng]
    weight_row = rows.Humidity
    # append the list to the final list 
    location_row_list.append(location_row) 
    weight_row_list.append(weight_row) 
    row_list.append(my_list) 
    
# Print the list 
print(row_list[:5])
print(location_row_list[:5])
print(weight_row_list[:5])
# Out:
# [[10.18, -65.04, 74.0], [-54.07, 132.47, 56.0], [67.13, 107.26, 93.0], [89.15, -80.58, 54.0], [-55.51, -99.24, 92.0]]
# [[10.18, -65.04], [-54.07, 132.47], [67.13, 107.26], [89.15, -80.58], [-55.51, -99.24]]
# [74.0, 56.0, 93.0, 54.0, 92.0]

# %%
# Ignore next two lines - test data
#location_row_list = [[61.43, -176.68], [41.2, 144.33], [-52.15, -173.09], [19.17, 19.35], [65.99, -63.81]]
#weight_row_list = [81.0, 89.0, 78.0, 49.0, 51.0]
# Customize the size of the figure
figure_layout = {
    'width': '600px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
#fig = gmaps.figure(layout=figure_layout)
fig = gmaps.figure(map_type='SATELLITE') 
new_york_coordinates = (40.75, -74.00)
fig = gmaps.figure(center=new_york_coordinates, zoom_level=2)
# Assign the marker layer to a variable
#markers = gmaps.marker_layer(location_row_list)
# Add the layer to the map
#fig.add_layer(markers)
heatmap_layer = gmaps.WeightedHeatmap(locations=location_row_list, weights=weight_row_list)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
fig1 = gmaps.figure(map_type='HYBRID')
new_york_coordinates = (40.75, -74.00)
fig1 = gmaps.figure(center=new_york_coordinates, zoom_level=2)
heatmap = gmaps.heatmap_layer(location_row_list, weights=weight_row_list)
heatmap.max_intensity = 30
heatmap.point_radius =8
#heatmap.gradient = ['white', 'red']
fig1.add_layer(heatmap)
heatmap.gradient = [
    'white',
    'green',
    'red'
]
fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
city_data.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity      float64
# Cloudiness    float64
# Wind Speed    float64
# Country        object
# Date          float64
# dtype: object

# %%
ideal_weather_cities = city_data.loc[(city_data['Max Temp'] >= 70) 
                                     & (city_data['Max Temp'] <= 80) 
                                     & (city_data['Wind Speed'] < 10)
                                     & (city_data['Cloudiness'] == 0)]
ideal_weather_cities
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 65         katobu  -6.05  124.64     74.34      90.0         0.0        5.23
# 82         castro -46.25 -100.95     70.93      57.0         0.0        6.13
# 108     samarinda  -0.69  118.13     73.63      96.0         0.0        1.05
# 145  komsomolskiy  69.16  173.26     73.40      46.0         0.0        6.93
# 194         mweka  -4.18   21.36     74.21      31.0         0.0        0.81
# 252       amuntai  -1.73  114.29     74.10      94.0         0.0        0.18
# 299        ca mau   8.92  103.60     77.81      87.0         0.0        1.50
# 312        malibu  33.76 -119.03     75.99      81.0         0.0        6.73
# 318      tayirove  46.44   30.57     78.80      50.0         0.0        6.71
# 352        lenine  45.08   35.98     73.56      72.0         0.0        1.14
# 447    chortomlyk  47.92   34.27     75.99      50.0         0.0        6.80
# 487     ostringen  49.16    8.75     75.00      42.0         0.0        6.15
# 503        vrable  48.31   18.33     77.00      73.0         0.0        1.86
# 569      karlovac  45.34   15.68     73.00      83.0         0.0        0.96
#
#     Country          Date
# 65       ID  1.595358e+09
# 82       BR  1.595358e+09
# 108      ID  1.595358e+09
# 145      UZ  1.595358e+09
# 194      CD  1.595358e+09
# 252      ID  1.595358e+09
# 299      VN  1.595358e+09
# 312      US  1.595358e+09
# 318      UA  1.595358e+09
# 352      UA  1.595358e+09
# 447      UA  1.595358e+09
# 487      DE  1.595358e+09
# 503      SK  1.595358e+09
# 569      HR  1.595358e+09

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
locations = ideal_weather_cities[['Lat', 'Lng']]
city_locations = ideal_weather_cities['City']
country_locations = ideal_weather_cities['Country']
weights = ideal_weather_cities['Humidity']

fig3 = gmaps.figure(map_type='TERRAIN') 
new_york_coordinates = (40.75, -74.00)
fig3 = gmaps.figure(center=new_york_coordinates, zoom_level=1)
heatmap_layer = gmaps.WeightedHeatmap(locations=locations, weights=weights)
fig3.add_layer(heatmap_layer)
fig3
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# geocoordinates
# Ignore next 3 lines - for testing only
#target_coordinates = "43.6187102, -116.2146068"
#target_coordinates = "61.43, -176.68"
#target_coordinates = f'{location_row_list[0][0]}, {location_row_list[0][1]}'
target_coordinates = []
target_search = ""
target_radius = 5000
target_type = "hotel"

hotel_name = []
city_name = []
country_name = []

#for x in range(0,1):
for index, row in locations.iterrows():
    #target_coordinates.append([row['Lat'], row['Lng']])
    # set up a parameters dictionary
    params = {
        "location": f"{row['Lat']}, {row['Lng']}",
#        "location":f'{target_coordinate[0]}, {target_coordinate[1]}',
#        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": g_key
    }
    #print(params)
    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params)
    # convert response to json
    places_data = response.json()
    print(json.dumps(places_data, indent=4, sort_keys=True))
    # Print the name of the first hotel that appears in city within 5000 meters of coordinates
    if places_data['status'] != "ZERO_RESULTS":       
        print('-----------------------------------')
        target_coordinates.append([row['Lat'], row['Lng']])
        city_name.append(city_locations[index])
        country_name.append(country_locations[index])
        try:
            hotel_name.append(places_data["results"][1]["name"])          
            #city_name.append(places_data["results"][0]["name"])
        except:
            hotel_name.append('NaN')
            #city_name.append(places_data["results"][0]["name"])
    #This json does not have country name, so have to do another API lookup for the country
# Out:
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -1.6942357,
#                     "lng": 114.2907785
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -1.692887619708498,
#                         "lng": 114.2920959802915
#                     },
#                     "southwest": {
#                         "lat": -1.695585580291502,
#                         "lng": 114.2893980197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "c7b0dd458d2a1664b5baa744c5cab7bb255f8a48",
#             "name": "Ud Sumber Rezeki",
#             "place_id": "ChIJtfj6XWN5-y0R07Bp3zxQk2M",
#             "plus_code": {
#                 "compound_code": "874R+88 Timpa, Danau Pantau, Kapuas Regency, Central Kalimantan, Indonesia",
#                 "global_code": "6PCP874R+88"
#             },
#             "reference": "ChIJtfj6XWN5-y0R07Bp3zxQk2M",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Jalan Palangkaraya-Buntok, Muroi Raya"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -1.6942357,
#                     "lng": 114.2907785
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -1.692887619708498,
#                         "lng": 114.2920959802915
#                     },
#                     "southwest": {
#                         "lat": -1.695585580291502,
#                         "lng": 114.2893980197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "682eb6083a96a25762a4f289cc101f628357823e",
#             "name": "Agen Gas Lpj 3 Kg",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJ0fTUkH15-y0RYeo_CSg_FtQ",
#             "plus_code": {
#                 "compound_code": "874R+88 Timpa, Danau Pantau, Kapuas Regency, Central Kalimantan, Indonesia",
#                 "global_code": "6PCP874R+88"
#             },
#             "reference": "ChIJ0fTUkH15-y0RYeo_CSg_FtQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Jalan Palangkaraya-Buntok, Muroi Raya"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -1.6942357,
#                     "lng": 114.2907785
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -1.692887619708498,
#                         "lng": 114.2920959802915
#                     },
#                     "southwest": {
#                         "lat": -1.695585580291502,
#                         "lng": 114.2893980197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "3594785f0ef5626fab665a06a4d2a166cc7a78bc",
#             "name": "Ud Sumber Rezeki",
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114300710216482877730\">Norman Thohir</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADrOe56kJeHSbAwcOWpfsxv5SYHfj6Qsd635B0znorIgQwd6aq_rl-Y_9He30qPhB5fO78JbOA9B6yrurKeVjwfyMEP4dBdxztavYx2TvfhRhuPNb9fTNoXPZv1ZlkbX8EhBRQi-bYGOu3Ws9u0-FtlDcGhTyKsbnR_9Sm9onzWjwtk0KXwpfjA",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJ15nu8qZ5-y0RrXXZR9_gZbg",
#             "plus_code": {
#                 "compound_code": "874R+88 Timpa, Danau Pantau, Kapuas Regency, Central Kalimantan, Indonesia",
#                 "global_code": "6PCP874R+88"
#             },
#             "rating": 5,
#             "reference": "ChIJ15nu8qZ5-y0RrXXZR9_gZbg",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Jalan Palangkaraya-Buntok, Muroi Raya"
#         }
#     ],
#     "status": "OK"
# }
# -----------------------------------
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "CqQ

#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJqZriFVotxkARpnU_cfYHd9A",
#             "plus_code": {
#                 "compound_code": "CJH5+PQ Prylymans'ke, Odessa Oblast, Ukraine",
#                 "global_code": "8GRGCJH5+PQ"
#             },
#             "rating": 4.3,
#             "reference": "ChIJqZriFVotxkARpnU_cfYHd9A",
#             "scope": "GOOGLE",
#             "types": [
#                 "florist",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 12,
#             "vicinity": "\u0443\u043b. \u041d\u043e\u0432\u0430\u044f, \u041e\u0434\u0435\u0441\u0441\u043a\u0430\u044f \u043e\u0431\u043b., \u041f\u0440\u0438\u043b\u0438\u043c\u0430\u043d\u0441\u043a\u043e\u0435"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 46.4678353,
#                     "lng": 30.5633416
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46.4692111302915,
#                         "lng": 30.5647882802915
#                     },
#                     "southwest": {
#                         "lat": 46.4665131697085,
#                         "lng": 30.5620903197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png",
#             "id": "7a9e6a43883d778982a046d83f100712bb3669b2",
#             "name": "Velykodalnytska School",
#             "photos": [
#                 {
#                     "height": 853,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111766776307396876168\">\u041c\u0438\u0445\u0430\u0438\u043b</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAvbUPPxkzapS84WEibpjKizrNtAzJza-l6hmoBQ2_AJWZPlOxNvn9P3OjRHwche17OJB04Kjbhk0OADg2vtv2bmaNX9ZjW_lgGww-lqmmjdW7oAO69B2ft5wQz8qDbOHQEhA9VUsIg8Zb1H5dxqCQVxPfGhQ4SSX-2ls7aDbWFIsJslD2e8yI2Q",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJX5x5gfMsxkARz2bdJxwv3xc",
#             "plus_code": {
#                 "compound_code": "FH97+48 Velykyi Dal'nyk, Odessa Oblast, Ukraine",
#                 "global_code": "8GRGFH97+48"
#             },
#             "rating": 4.1,
#             "reference": "ChIJX5x5gfMsxkARz2bdJxwv3xc",
#             "scope": "GOOGLE",
#             "types": [
#                 "school",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 20,
#             "vicinity": "Bohdana Khmelnytskoho Street, Velykyi Dal'nyk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 46.41782560000001,
#                     "lng": 30.5961165
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46.4191432302915,
#                         "lng": 30.5975416802915
#                     },
#                     "southwest": {
#                         "lat": 46.4164452697085,
#                         "lng": 30.5948437197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/gas_station-71.png",
#             "id": "8d95fb3b7f77d073924f307d396d9be043901db4",
#             "name": "Ukrnafta",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3085,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116194665534478458648\">Oleh Medynskyi</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADXnoFEUQAAamInQfJjncpLjOqmKZy75KfucNQTOkqRjo_f3IR1un_D8mpJtJrvy0nCazf90iE8pYVOuHELpXKsw3quS4wPLMbIMNv13gBSVEMxqjXXUEUvisy68pkaF1EhD0UODQqAgAAHLp4E1V_CZNGhTthDWORLG2TmYb5jMnzxtxJcfvgw",
#                     "width": 4628
#                 }
#             ],
#             "place_id": "ChIJ2THWbazSx0AR_Yj1xeXLGDs",
#             "plus_code": {
#                 "compound_code": "CH9W+4C Velykyi Dal'nyk, Odessa Oblast, Ukraine",
#                 "global_code": "8GRGCH9W+4C"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ2THWbazSx0AR_Yj1xeXLGDs",
#             "scope": "GOOGLE",
#             "types": [
#                 "gas_station",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 44,
#             "vicinity": "P70 road"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 46.46946,
#                     "lng": 30.5631251
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46.4707754302915,
#                         "lng": 30.5644131802915
#                     },
#                     "southwest": {
#                         "lat": 46.4680774697085,
#                         "lng": 30.5617152197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "b9b9511221c55c98501dcbad5184ea80bdd7469e",
#             "name": "\u0422\u0430\u0432\u0435\u0440\u043d\u0430",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100642068721712376848\">\u0410\u043a\u043a\u0430\u0443\u043d\u0442 \u0410\u0434\u043c\u0438\u043d</a>"
#                     ],
#                     "photo_reference": "CmRaAAA

#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2560,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103655970262555096641\">\u0421\u0430\u0448\u0430 \u0425\u0430\u0440\u0438\u043d\u043e\u0432</a>"
#                     ],
#                     "photo_reference": "CmRaAAAARcD-mkpvYDpvlE5XQB5ZFSYWuXmZWAz2aoMhEMswyWDFWf5PlOYCdVZnt1kwMzpw79tb66XAgh7xer_Ufajxght4TMwA6Zw2_WkrsWcTznOd6yTGrUDOr2MGmBaLIAdzEhAbTDZvRhMak2QFU2qR0BSdGhRC2YzKEEQ2EpZ9ltZn8KKjWeRqVA",
#                     "width": 1536
#                 }
#             ],
#             "place_id": "ChIJMaiepI8sxkAR4MU9sZY33eU",
#             "plus_code": {
#                 "compound_code": "FGCW+2C Odesa, Odessa Oblast, Ukraine",
#                 "global_code": "8GRGFGCW+2C"
#             },
#             "rating": 3.5,
#             "reference": "ChIJMaiepI8sxkAR4MU9sZY33eU",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 6,
#             "vicinity": "21-\u0439 \u043a\u043c. \u0442\u0440\u0430\u0441\u0441\u044b \u041e\u0434\u0435\u0441\u0441\u0430-\u0420\u0435\u043d\u0438,\u0441. \u0412\u0435\u043b\u0438\u043a\u0438\u0439 \u0414\u0430\u043b\u044c\u043d\u0438\u043a, Odesa"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 46.450749,
#                     "lng": 30.6186381
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46.4522690802915,
#                         "lng": 30.6199507302915
#                     },
#                     "southwest": {
#                         "lat": 46.4495711197085,
#                         "lng": 30.6172527697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "38e9d22209dcce492317c56bd061942b96dcace1",
#             "name": "Sklady",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111527274721282712547\">vlabimir mihoi</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAMC4OifKZaOMrEpnigzMCoUf0SOj524_Fj9QlOnMowR-lbz8utQKVORWNd_I05hVWYOTdlmMMCBUwNutcJS-LjHRl8sb4P8jhnmi8qPD-k6gU8lkkHj-OMl5Eqp27gV1NEhDt3zOtvlPmVsMllwJkHvRrGhSvMOWOLZAp_--5gk8BoEUC22wd-w",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJEX9gX3EtxkARo0WbQ1hYXHc",
#             "plus_code": {
#                 "compound_code": "FJ29+7F Avanhard, Odessa Oblast, Ukraine",
#                 "global_code": "8GRGFJ29+7F"
#             },
#             "rating": 3.7,
#             "reference": "ChIJEX9gX3EtxkARo0WbQ1hYXHc",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "Ukraine"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 46.47340029999999,
#                     "lng": 30.5579871
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46.47517623029149,
#                         "lng": 30.5586779
#                     },
#                     "southwest": {
#                         "lat": 46.47247826970849,
#                         "lng": 30.55591470000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png",
#             "id": "6674f989daf11e5cb8bf7d8559616ba196127f90",
#             "name": "Oschadbank",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJwWWC9IksxkARZAvVJFKOEEs",
#             "plus_code": {
#                 "compound_code": "FHF5+95 Velykyi Dal'nyk, Odessa Oblast, Ukraine",
#                 "global_code": "8GRGFHF5+95"
#             },
#             "rating": 1,
#             "reference": "ChIJwWWC9IksxkARZAvVJFKOEEs",
#             "scope": "GOOGLE",
#             "types": [
#                 "bank",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "\u0441, Bohdana Khmelnytskoho Street, 3, Velykyi Dal'nyk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 46.4565671,
#                     "lng": 30.6142445
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46.45767918029151,
#                         "lng": 30.6156403802915
#                     },
#                     "southwest": {
#                         "lat": 46.45498121970851,
#                         "lng": 30.6129424197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "5f96d9a1eac19cf5b204a08d3f7995f0e96ca539",
#             "name": "\u0410\u0440\u043a\u0441 \u0421\u0442\u0430\u043b\u044c",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107480334682998807720\">\u0412\u0438\u0442\u0430\u043b\u0438\u0439 \u041e\u0434\u0435\u0441\u0441\u0430</a>"
#                     ],
#                     "photo_reference": "CmRaAAA
Odessa Oblast, Ukraine",
#                 "global_code": "8GRGFHF4+MM"
#             },
#             "rating": 4.1,
#             "reference": "ChIJxd4WvfQsxkART6zyh64Frto",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 90,
#             "vicinity": "\u0412\u0435\u043b\u0438\u043a\u0438\u0439 \u0414\u0430\u043b\u044c\u043d\u0438\u043a, \u0411\u043e\u0433\u0434\u0430\u043d\u0430 \u0425\u043c\u0435\u043b\u044c\u043d\u0438\u0446\u044c\u043a\u043e\u0433\u043e, 54, Velykyi Dal'nyk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 46.45601200000001,
#                     "lng": 30.616364
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46.45749493029151,
#                         "lng": 30.61768533029149
#                     },
#                     "southwest": {
#                         "lat": 46.45479696970851,
#                         "lng": 30.61498736970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "129925210575e3f179d4cbd1b14efdbfa77ec759",
#             "name": "\u0421\u0430\u0436\u0435\u043d\u0446\u044b \u044f\u0433\u043e\u0434\u043d\u044b\u0445, \u043e\u0440\u0435\u0445\u0430, \u0443\u0434\u043e\u0431\u0440\u0435\u043d\u0438\u044f \u041e\u0434\u0435\u0441\u0441\u0430. \u041e\u0421\u0413 \u0421\u044b\u0440\u043e\u0432\u0435\u0442\u043d\u0438\u043a",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 600,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114717052911109665822\">\u0421\u0430\u0436\u0435\u043d\u0446\u044b \u044f\u0433\u043e\u0434\u043d\u044b\u0445, \u043e\u0440\u0435\u0445\u0430, \u0443\u0434\u043e\u0431\u0440\u0435\u043d\u0438\u044f \u041e\u0434\u0435\u0441\u0441\u0430. \u041e\u0421\u0413 \u0421\u044b\u0440\u043e\u0432\u0435\u0442\u043d\u0438\u043a</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAj86Lv8SQBi5tCl1V6BTEuSCeNRX8Mg27wezpuIGyGqVoJpTlNZrEZtKOo61GfKBVwnjAE8O4CKxfsJbe6N-jLAJArllDMdPdnvQMvVcYUxGtJ7SoXdPQeVAQ2BxjLxBgEhDnw2OIUEY0r-9EuBRSrHyBGhRS3F49E4QN8i6bnpKniBeZWrhMyw",
#                     "width": 2000
#                 }
#             ],
#             "place_id": "ChIJE8XHM3UtxkARMfOBCoxq1Ho",
#             "plus_code": {
#                 "compound_code": "FJ48+CG Avanhard, Odessa Oblast, Ukraine",
#                 "global_code": "8GRGFJ48+CG"
#             },
#             "rating": 5,
#             "reference": "ChIJE8XHM3UtxkARMfOBCoxq1Ho",
#             "scope": "GOOGLE",
#             "types": [
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "ul. Teplichnaya \u041e\u0434\u0435\u0441\u0441\u0430, \u0410\u0432\u0430\u043d\u0433\u0430\u0440\u0434"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 46.4746816,
#                     "lng": 30.5569214
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46.4760981802915,
#                         "lng": 30.55821418029149
#                     },
#                     "southwest": {
#                         "lat": 46.4734002197085,
#                         "lng": 30.55551621970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/pharmacy_cross-71.png",
#             "id": "6f3ff6e595881de3367fd85741bdc0b7db80dd05",
#             "name": "Apteka 24",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJ9SV5-oksxkARc4z0s7ZFxzw",
#             "plus_code": {
#                 "compound_code": "FHF4+VQ Velykyi Dal'nyk, Odessa Oblast, Ukraine",
#                 "global_code": "8GRGFHF4+VQ"
#             },
#             "rating": 4.9,
#             "reference": "ChIJ9SV5-oksxkARc4z0s7ZFxzw",
#             "scope": "GOOGLE",
#             "types": [
#                 "pharmacy",
#                 "health",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 7,
#             "vicinity": "\u0415 87, Velykyi Dal'nyk"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 46.4749756,
#                     "lng": 30.5568543
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46

#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJhYFA-6gyxkARQNLkTlPf1h4",
#             "plus_code": {
#                 "compound_code": "CJF9+78 Prylymans'ke, Odessa Oblast, Ukraine",
#                 "global_code": "8GRGCJF9+78"
#             },
#             "rating": 4,
#             "reference": "ChIJhYFA-6gyxkARQNLkTlPf1h4",
#             "scope": "GOOGLE",
#             "types": [
#                 "city_hall",
#                 "local_government_office",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "Prylymans'ke"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 46.4568737,
#                     "lng": 30.68213890000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 46.5083249,
#                         "lng": 30.7455921
#                     },
#                     "southwest": {
#                         "lat": 46.41352,
#                         "lng": 30.6116849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png",
#             "id": "1f4683ee79282d1a8a2e1f758cc67961d6fd8e78",
#             "name": "Malynovsky Raion",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106300866477244977030\">mmodelscomua</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAbJYFmdBAuqLPM11_bWPC2c0ibX39zYcEMZ37D9KFkR-QvObakFab6_yLZyJ4oZjNyMnqVVyMkKhBY1EVz0XfF2Vko49_sl_9Y0Mo4HmgaCAPL4d6TwlEwKhW23ePgDFYEhDp5NVbWTDLOQhJSZCf_uGrGhQPKQoAO6cQduvxe_3XWakR3pS2nw",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJbRYnemwyxkARSq0p3GfmQC0",
#             "reference": "ChIJbRYnemwyxkARSq0p3GfmQC0",
#             "scope": "GOOGLE",
#             "types": [
#                 "sublocality_level_1",
#                 "sublocality",
#                 "political"
#             ],
#             "vicinity": "Malynovsky Raion"
#         }
#     ],
#     "status": "OK"
# }
# -----------------------------------
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "ZERO_RESULTS"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.94270259999999,
#                     "lng": 34.22816410000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.9457989,
#                         "lng": 34.233553
#                     },
#                     "southwest": {
#                         "lat": 47.938959,
#                         "lng": 34.21308
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png",
#             "id": "c57c70502df562f041407ba4da03e820affdccfa",
#             "name": "Holovkove",
#             "photos": [
#                 {
#                     "height": 2248,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107715724536135388753\">\u0410\u043b\u0435\u043a\u0441\u0430\u043d\u0434\u0440 \u041a\u0430\u0440\u043f\u0435\u043d\u043a\u043e</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5uD0v7ZsKfmOlGIsv4uxprtD8-wOda69cAVtPBuidwLah8MgofhCdXNLxRV0U3R4wVY9nL57RQD4ATLHDUZVxlXoSXkdHWDMaEWgZGKQVzie-nSz9Ab5YnYAR7o9IRMHEhCCGdV7nw3AvR7hm4za1kHcGhQOU40jw_1MKjxRRm3yeQFU7KopDQ",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJ088vN29x20ARfI5-Cvc3yFg",
#             "reference": "ChIJ088vN29x20ARfI5-Cvc3yFg",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Holovkove"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 47.906387,
#                     "lng": 34.32434
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.9077756302915,
#                         "lng": 34.3259950802915
#                     },
#                     "southwest": {
#                         "lat": 47.9050776697085,
#                         "lng": 34.3232971197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "89a136eebd8eab1cf8d4cbabf29748b022a07fb1",
#             "name": "Krynychuvat\u00b7s\u02b9ka Sil\u02b9s\u02b9ka Rada",
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116184437095388200503\">Travel road trucking AVautosystem</a>"
#                     ],
# ...
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Trg S. Radi\u0107a bb, Vojni\u0107"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 45.3250638,
#                     "lng": 15.6962323
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.3264577302915,
#                         "lng": 15.6972315802915
#                     },
#                     "southwest": {
#                         "lat": 45.3237597697085,
#                         "lng": 15.6945336197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "2fc948907b15a2bd2cad9a5f2a3c49df31a0bcb2",
#             "name": "CENTAR ZA CIVILNE INICIJATIVE",
#             "place_id": "ChIJW_iXsE8cZEcRaNgU0yXeTxM",
#             "reference": "ChIJW_iXsE8cZEcRaNgU0yXeTxM",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Kralja Petra Kre\u0161imira IV. 2, Vojni\u0107"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 45.32672729999999,
#                     "lng": 15.6946892
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.3280999802915,
#                         "lng": 15.6960741802915
#                     },
#                     "southwest": {
#                         "lat": 45.32540201970851,
#                         "lng": 15.6933762197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "482d4c7e7a8223e6708f12740f14533f9c50c8fb",
#             "name": "OFARM d.o.o",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 667,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113998615571068483426\">OFARM d.o.o</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaeVgtFiRSXKQJS2-9XnvE2I8mh7zjbYUz2NRYbxXqVcOON_lX6_5f8ABFVWGUmybDDRii8Daf6nYFpq_2Ujja00cQ0KCeBKl1DQpji7emRE-Vs5T7iLdHdxiWwJ5AmEjEhCrccb3LvxafulQn0Hpjd1uGhTfp1siBJ5CXBvLHu7eOKaOLTrLHA",
#                     "width": 1000
#                 }
#             ],
#             "place_id": "ChIJpQCCnE8cZEcRK23jzEj0--Y",
#             "plus_code": {
#                 "compound_code": "8MGV+MV Vojni\u0107, Croatia",
#                 "global_code": "8FQQ8MGV+MV"
#             },
#             "reference": "ChIJpQCCnE8cZEcRK23jzEj0--Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Karlova\u010dka ulica 7, Vojni\u0107"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 45.32602199999999,
#                     "lng": 15.697337
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.3272483302915,
#                         "lng": 15.6987854802915
#                     },
#                     "southwest": {
#                         "lat": 45.3245503697085,
#                         "lng": 15.6960875197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/civic_building-71.png",
#             "id": "de006bae4df9b8916df4704cc95968857a4e996b",
#             "name": "GEOPROSTOR d.o.o",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 600,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107623919784506773198\">GEOPROSTOR d.o.o</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAULYMJ8BW605a2q1CxxDWfNsrhn6fEIsmmnknnzQjdUP-1sWCIyTXUsCMJhT6Y4ALIBnF9I1CfMasSMiqSY_-n5ezjw5E3mjrovyHXCYcCKov6bpFwN1VBqdoDHHjSQL7EhBAElePwUXi4Fp3cbi0zSa7GhTtzcbc0JCM7WMqJ5_8fBx0aodY-g",
#                     "width": 600
#                 }
#             ],
#             "place_id": "ChIJoZ24Pk8cZEcRFLd86GpzRGk",
#             "plus_code": {
#                 "compound_code": "8MGW+CW Vojni\u0107, Croatia",
#                 "global_code": "8FQQ8MGW+CW"
#             },
#             "reference": "ChIJoZ24Pk8cZEcRFLd86GpzRGk",
#             "scope": "GOOGLE",
#             "types": [
#                 "local_government_office",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Karlova\u010dka ulica 4A"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 45.3247697,
#                     "lng": 15.6952043
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.32600953029149,
#                         "lng": 15.6965271302915
#                     },
#                     "southwest": {
#                         "lat": 45.3233115697085,
#                         "lng": 15.6938291697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/post_office-71.png",
#             "id": "f816f3e4c7adb9e8b1cf9f8c25488eb546073e58",
#             "name": "Po\u0161tanski ured 47220 Vojni\u0107",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106471692994621999557\">Zdenko Brkanic</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA1SJB06JBTOTOeYZHRO6mToawuJpw_SHn27irDg7kF7W6yLrC21U19VKl2FFGdrxKUlG9M29vklTheIk7sYtER1QKOBV2rOwqZpGwO8Zk-j3G-2EMXefXaIiLaSZnUwvHEhA5Q83DAQPI6QEBj0ZWEs2KGhShqn_wn9Qws61Y3KTTSeySqoFsNA",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJWxhHgk8cZEcRDp3RFVlmi48",
#             "plus_code": {
#                 "compound_code": "8MFW+W3 Vojni\u0107, Croatia",
#                 "global_code": "8FQQ8MFW+W3"
#             },
#             "rating": 4,
#             "reference": "ChIJWxhHgk8cZEcRDp3RFVlmi48",
#             "scope": "GOOGLE",
#             "types": [
#                 "post_office",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Ulica Andrije Hebranga 6, Vojni\u0107"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 45.3247589,
#                     "lng": 15.695204
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.3260938302915,
#                         "lng": 15.6966624302915
#                     },
#                     "southwest": {
#                         "lat": 45.3233958697085,
#                         "lng": 15.6939644697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/atm-71.png",
#             "id": "7cc97cc89802d67328a282e8471f20382d29984e",
#             "name": "Hrvatska po\u0161tanska banka - ATM/Bankomat",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJeTBGgk8cZEcRCVeH1NVLqbI",
#             "plus_code": {
#                 "compound_code": "8MFW+W3 Vojni\u0107, Croatia",
#                 "global_code": "8FQQ8MFW+W3"
#             },
#             "reference": "ChIJeTBGgk8cZEcRCVeH1NVLqbI",
#             "scope": "GOOGLE",
#             "types": [
#                 "atm",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Vojni\u0107"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 45.3248682,
#                     "lng": 15.6955861
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.3262251302915,
#                         "lng": 15.69687338029151
#                     },
#                     "southwest": {
#                         "lat": 45.32352716970851,
#                         "lng": 15.6941754197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "d83a27f22e6438c48e955d2cf44bd7a7d5b47a4e",
#             "name": "Tisak",
#             "place_id": "ChIJm_b0ZQ7yZkcRkxX3Lc6zFmI",
#             "plus_code": {
#                 "compound_code": "8MFW+W6 Karlovac, Croatia",
#                 "global_code": "8FQQ8MFW+W6"
#             },
#             "reference": "ChIJm_b0ZQ7yZkcRkxX3Lc6zFmI",
#             "scope": "GOOGLE",
#             "types": [
#                 "convenience_store",
#                 "book_store",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "vicinity": "Ulica Stjepana Radi\u0107a, Karlovac"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 45.3767541,
#                     "lng": 15.6957879
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.3778883802915,
#                         "lng": 15.6969017802915
#                     },
#                     "southwest": {
#                         "lat": 45.3751904197085,
#                         "lng": 15.69420381970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "bf672e06032bfedf201b72c821cd063594745de2",
#             "name": "Ekodrom",
#             "photos": [
#                 {
#                     "height": 3648,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106670505298857232645\">clex otron</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATMVM6HvUE8KhnHEUBjnDK-6cX_XSicl48ek4gXHFkQ6rU8XNBzGgAxiRaKg2n-LKthz0MqBdJOmNheF_do9_pLpXQZOvCbrdZnvMN2YsP4S9gWwCP1a2IVx42DUIfvWoEhBFtq1W12wF8iG1KSFjYc78GhSh7NEDI1weP3DZUA3VahnaDlgWhg",
#                     "width": 5472
#                 }
#             ],
#             "place_id": "ChIJfc6TFM8eZEcRDy-EWdoGvlc",
#             "plus_code": {
#                 "compound_code": "9MGW+P8 Bukovica Utinjska, Croatia",
#                 "global_code": "8FQQ9MGW+P8"
#             },
#             "rating": 5,
#             "reference": "ChIJfc6TFM8eZEcRDy-EWdoGvlc",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "Bukovica Utinjska"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 45.3244689,
#                     "lng": 15.6948379
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.32587608029149,
#                         "lng": 15.6962008302915
#                     },
#                     "southwest": {
#                         "lat": 45.32317811970849,
#                         "lng": 15.6935028697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "630ed84e5c2412723a67be5c01beb1fd5d7a333b",
#             "name": "Vodovod i odvodnja Vojni\u0107 doo",
#             "place_id": "ChIJ5efIhk8cZEcRp-cnNfCKHoA",
#             "plus_code": {
#                 "compound_code": "8MFV+QW Vojni\u0107, Croatia",
#                 "global_code": "8FQQ8MFV+QW"
#             },
#             "reference": "ChIJ5efIhk8cZEcRp-cnNfCKHoA",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Ulica Andrije Hebranga 9, Vojni\u0107"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 45.3289128,
#                     "lng": 15.6912252
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.3303680302915,
#                         "lng": 15.6927310802915
#                     },
#                     "southwest": {
#                         "lat": 45.3276700697085,
#                         "lng": 15.6900331197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "f4c4d38abe2452bcdf43775e60f1d9f54acdd5c5",
#             "name": "Centar za rehabilitaciju Nada",
#             "place_id": "ChIJHd8Q9xsdZEcRlHMLsEnIRJg",
#             "plus_code": {
#                 "compound_code": "8MHR+HF Vojni\u0107, Croatia",
#                 "global_code": "8FQQ8MHR+HF"
#             },
#             "reference": "ChIJHd8Q9xsdZEcRlHMLsEnIRJg",
#             "scope": "GOOGLE",
#             "types": [
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Gornji Vojnic 2a, Vojni\u0107"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 45.2914376,
#                     "lng": 15.6367372
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 45.3332413,
#                         "lng": 15.6614254
#                     },
#                     "southwest": {
#                         "lat": 45.271161,
#                         "lng": 15.5955482
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png",
#             "id": "f929c9b5d90797c53a22bfae86139543d6655cb4",
#             "name": "Buda\u010dka Rijeka",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102352494066830786043\">Maria MV</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAYnSCQ0kK1pSTbxAiMpXL43jbNONmEMNbWYlP24mwsMsP_qR1F2qcJ1eKzsLgmJr9347llA-0JaGQsttHg_Rv5uFoUGw8CQnmikjOtKUvwZN_Yp15zFVL4EjVejCjTElmEhDQ9vDV3uWzMt2yc8myTJDiGhTpBqZyCJ7oR974AvHdxAdbI6OhKg",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJA_T8eWgbZEcR6siFT015xxs",
#             "reference": "ChIJA_T8eWgbZEcR6siFT015xxs",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Buda\u010dka Rijeka"
#         }
#     ],
#     "status": "OK"
# }
# -----------------------------------

# %%
print(len(hotel_name))
print(len(city_name))
print(hotel_name)
print(city_name)
# Out:
# 6
# 6
# ['Agen Gas Lpj 3 Kg', 'Mramor, Hranit', 'Krynychuvat·sʹka Silʹsʹka Rada', 'Gaststätte Krone', 'Municipal office', 'Pbz Vojnić']
# ['amuntai', 'tayirove', 'chortomlyk', 'ostringen', 'vrable', 'karlovac']

# %%
    # Print the name of the first hotel that appears in city within 5000 meters of coordinates
    #print(places_data["results"][0]["name"])
    #print(places_data["results"][0]["vicinity"])
    #print(places_data["results"][1]["name"])
    #print(places_data["results"][1]["vicinity"])
    #hotel_name = places_data["results"][1]["name"]
    #city_name = places_data["results"][0]["name"]
    #This json does not have country name, so have to do another API lookup for the country

# %%
#API lookup for country of the city of hotel
country_name_alt = []
# Target cities
for target_city in city_name:
    if target_city != 'Nan':
        # Build the endpoint URL
        target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
            'address={0}&key={1}').format(target_city, g_key)

        # Run a request to endpoint and convert result to json
        geo_data = requests.get(target_url).json()
        # Print the json
        #print(json.dumps(geo_data, indent=4, sort_keys=True))
        
        # Extract Country
        try:
            country = geo_data["results"][0]["address_components"][3]["long_name"]
            country_name_alt.append(country)
        except:
            country_name_alt.append('NaN')
            
print(len(country_name_alt))
print(len(country_name))
# Out:
# 6
# 6

# %%
print(country_name)
print(country_name_alt)
# Out:
# ['ID', 'UA', 'UA', 'DE', 'SK', 'HR']
# ['Kabupaten Hulu Sungai Utara', 'Ukraine', 'Ukraine', 'Baden-Württemberg', 'Slovakia', 'NaN']

# %%
hotels = []
hotel_locations = []
for i in range(len(hotel_name)):
    # build dictionary for hotels and text box in the marker layer
    #target_coord = (43.6187102, -116.2146068)
    hotels.append({"Hotel": hotel_name[i],
        "location": target_coordinates[i],
        #        "location": [location_row_list[i][0],location_row_list[i][1]],
        "City": city_name[i],
        "Country": country_name[i]})
#print(hotels)
for hotel in hotels:
    print(hotel)
    hotel_locations.append(hotel['location'])

#hotel_locations = [hotel['location'] for hotel in hotels]
print(len(hotel_locations))
info_box_template = """
<dl>
<dt>Hotel</dt><dd>{Hotel}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
hotel_info = [info_box_template.format(**hotel) for hotel in hotels]
print(len(hotel_info))
print(hotel_locations)
print(hotel_info)
# Out:
# {'Hotel': 'Agen Gas Lpj 3 Kg', 'location': [-1.73, 114.29], 'City': 'amuntai', 'Country': 'ID'}
# {'Hotel': 'Mramor, Hranit', 'location': [46.44, 30.57], 'City': 'tayirove', 'Country': 'UA'}
# {'Hotel': 'Krynychuvat·sʹka Silʹsʹka Rada', 'location': [47.92, 34.27], 'City': 'chortomlyk', 'Country': 'UA'}
# {'Hotel': 'Gaststätte Krone', 'location': [49.16, 8.75], 'City': 'ostringen', 'Country': 'DE'}
# {'Hotel': 'Municipal office', 'location': [48.31, 18.33], 'City': 'vrable', 'Country': 'SK'}
# {'Hotel': 'Pbz Vojnić', 'location': [45.34, 15.68], 'City': 'karlovac', 'Country': 'HR'}
# 6
# 6
# [[-1.73, 114.29], [46.44, 30.57], [47.92, 34.27], [49.16, 8.75], [48.31, 18.33], [45.34, 15.68]]
# ['\n<dl>\n<dt>Hotel</dt><dd>Agen Gas Lpj 3 Kg</dd>\n<dt>City</dt><dd>amuntai</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel</dt><dd>Mramor, Hranit</dd>\n<dt>City</dt><dd>tayirove</dd>\n<dt>Country</dt><dd>UA</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel</dt><dd>Krynychuvat·sʹka Silʹsʹka Rada</dd>\n<dt>City</dt><dd>chortomlyk</dd>\n<dt>Country</dt><dd>UA</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel</dt><dd>Gaststätte Krone</dd>\n<dt>City</dt><dd>ostringen</dd>\n<dt>Country</dt><dd>DE</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel</dt><dd>Municipal office</dd>\n<dt>City</dt><dd>vrable</dd>\n<dt>Country</dt><dd>SK</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel</dt><dd>Pbz Vojnić</dd>\n<dt>City</dt><dd>karlovac</dd>\n<dt>Country</dt><dd>HR</dd>\n</dl>\n']

# %%
fig2 = gmaps.figure(map_type='HYBRID')
new_york_coordinates = (40.75, -74.00)
fig2 = gmaps.figure(center=new_york_coordinates, zoom_level=1)
marker_layer = gmaps.marker_layer(hotel_locations, info_box_content=hotel_info)
#print(marker_layer)
#fig = gmaps.figure()
fig2.add_layer(marker_layer)
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))
